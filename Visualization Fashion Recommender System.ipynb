# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('D:\DS Project 2020-21\styles.csv')
print(data.head())
# Out:
#       id gender masterCategory subCategory  articleType baseColour  season  \
# 0  15970    Men        Apparel     Topwear       Shirts  Navy Blue    Fall
# 1  39386    Men        Apparel  Bottomwear        Jeans       Blue  Summer
# 2  59263  Women    Accessories     Watches      Watches     Silver  Winter
# 3  21379    Men        Apparel  Bottomwear  Track Pants      Black    Fall
# 4  53759    Men        Apparel     Topwear      Tshirts       Grey  Summer
#
#      year   usage                             productDisplayName
# 0  2011.0  Casual               Turtle Check Men Navy Blue Shirt
# 1  2012.0  Casual             Peter England Men Party Blue Jeans
# 2  2016.0  Casual                       Titan Women Silver Watch
# 3  2011.0  Casual  Manchester United Men Solid Black Track Pants
# 4  2012.0  Casual                          Puma Men Grey T-shirt

# %%
#Genderwise categories
plt.figure(figsize=(12, 4))
data['gender'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#Categorywise graph
plt.figure(figsize=(12, 4))
data['masterCategory'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#Subcategoriwise plot
plt.figure(figsize=(16, 4))
data['subCategory'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#Basecolorwise graph
plt.figure(figsize=(16, 4))
data['baseColour'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#Seasons
data['season'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#Yearwise plot
data['year'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#Usagewise categories
plt.figure(figsize=(12, 4))
data['usage'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>
